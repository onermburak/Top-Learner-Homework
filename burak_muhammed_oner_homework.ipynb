# %%
""" Programı çalıştırmak için öncelikle öğrenci kaydı oluşturmalısınız. Ardından oluşturulan ad ve soyad bilgisi ile giriş yapmak zorundasınız.
Sistem size 3 hak vermektedir. Daha sonra en az 3 maksimum 5 ders olacak şekilde ders kaydı yapılacaktır. Midterm, final ve project notları girildikten sonra
en son aşamada harf notu ekrana yansıtılır ve tüm girdiler print fonksiyonu ile ekrana verilir. 
"""

enroll=[]
def students():
  name = input("Enter Your Name: ")
  surname = input("Enter Your Last Name: ")
  print("\n............Student Registration Successful............\n")
  global enroll
  enroll += ([name],[surname])
  return 

i=1
def logins():  
      for i in range(3):
        i +=1
        name2 = [input("Enter Your Name: ")]
        surname2 = [input("Enter Your Last Name: ")]
        
        if i==3:
            return "\n""**********Please Try Again Later**********""\n"
        
        elif enroll[0]==name2 and enroll[1]==surname2:
            print("\n............Welcome............\n")
            return "in"
            break          
        else:
            print( "\n""**********Please Try Again Later**********""\n")


lessons={"Mathematics":10,"Chemistry":11,"Physics":12,"Biology":13,"Literature":14}
lesson={}
def regis():
  for i in range(5):
    lesson1=int(input("\n""*************************""\n""Mathematics-10""\n""Chemistry-11""\n""Physics-12""\n""Biology-13""\n""Literature-14""\n""Exit-15""\n"))
    if lessons["Mathematics"] == lesson1:
      lesson["Mathematics"]=10    
    elif lessons["Chemistry"] == lesson1:
      lesson["Chemistry"]=11  
    elif lessons["Physics"] == lesson1:
      lesson["Physics"]=12  
    elif lessons["Biology"] == lesson1:
      lesson["Biology"]=13     
    elif lessons["Literature"]== lesson1:
      lesson["Literature"]=14  
    else:
      break
  if len(lesson)<3:
    print("\n............You Failed In Class............\n")
    return 
  else:
    return "in"

notes=()
def note_enter():
  midterm = int(input("Midterm: "))
  final = int(input("Final: "))
  project = int(input("Project: "))
  global notes
  notes += (midterm,final,project)

  print("\n............Notes Registration Successful............\n")
  return

def note_calculate():
  global result
  result = int(((notes[0]*0.3)+(notes[1]*0.5)+(notes[2]*0.2)))
  if result >= 90:
      print("\n""--AA--""\n")
  elif 70 < result < 90:
      print("\n""--BB--""\n")
  elif 50 < result < 70:
      print("\n""--CC--""\n")
  elif 30 < result < 50:
      print("\n""--DD--""\n")
  else:
      print("\n""--FF--""\n")
      print("Fail")
  return 


print("STUDENT AUTOMATION SYSTEM""\n".center(150))
print("(First Create Student Registration)".center(150))

while True:
  entering = int(input("STUDENT REGISTRATION-1""\n""STUDENT LOGIN-2""\n""COURSE REGISTRATION-3""\n""NOTE ENTRY-4""\n""NOTE CALCULATION-5""\n"))
  if entering ==1:
    students()
    print("\n",enroll,"\n")
    break

  else:
    print("\n""---------First Create Student Registration---------""\n") 

while True:
    entering = int(input("\n""STUDENT LOGIN-2""\n""COURSE REGISTRATION-3""\n""NOTE ENTRY-4""\n""NOTE CALCULATION-5""\n")) 
    if entering ==2:
      if logins() =="in":
        pass
      else:
        break
    else:
      print("\n""---------You Must Login---------""\n")

    while True:
      entering = int(input("\n""COURSE REGISTRATION-3""\n""NOTE ENTRY-4""\n""NOTE CALCULATION-5""\n"))
      if entering ==3:
          if regis()=="in":
            print("\n",lesson,"\n")
            break
          else:
              print(regis())
      else:
        print("\n""---------Course registration---------""\n") 

    while True:
      entering = int(input("\n""NOTE ENTRY-4""\n""NOTE CALCULATION-5""\n"))
      if entering ==4:
        note_enter()
        print("\n",notes,"\n")
        break
      
      else:
        print("\n""---------Note Entry---------""\n")            

    while True:
      entering = int(input("\n""NOTE CALCULATION-5""\n"))
      if entering ==5:
        note_calculate()
        print("\n",result,"\n")
        print(f'Enrolled Student: {enroll} {lessons} Chose Lessons.Total of All Exams: {result}')
        pass
      
      else:
        print("\n""---------Note Calculation---------""\n")
    break
